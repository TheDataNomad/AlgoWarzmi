# %% [markdown]
# # Pandas and Numpy

# %% [markdown]
# <ol>
#    <li> The data manipulation capabilities of pandas are built on top of the numpy library. In a way, numpy is a dependency of the pandas library. </li>
#
#    <li>Pandas is best at handling tabular data sets comprising different variable types (integer, float, double, etc.) In addition, the pandas library can also be used to perform even the most naive of tasks such as loading data or doing feature engineering on time series data. </li>
#    <li> Numpy is most suitable for performing basic numerical computations such as mean, median, range, etc. Alongside, it also supports the creation of multi-dimensional arrays. </li>
#
#    <li> Remember, python is a zero indexing language unlike R where indexing starts at one.</li>
#    <li> The best part of learning pandas and numpy is the strong active community support you'll get from around the world. </li>
#     </ol>

# %%
#if you don't have panadas
#!pip install pandas

import pandas as pd

# %%
#!wget "https://raw.githubusercontent.com/TheDataNomad/AlgoWarzmi/main/titanic.csv"

# %%
titanic_df = pd.read_csv("titanic.csv")
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Pandas methods 

#head and tail 
titanic_df.head()

titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#accessing rows
titanic_df.iloc[1]  # one row
titanic_df.loc[1]

# titanic_df.iloc[0:5] #multiple rows
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
#accessing columns
titanic_df["Name"].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
#accessing multiple columns
titanic_df[["Name",'Age']].head()
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
#accessing specific  columns and rows you use loc
titanic_df.loc[0:3,["Name",'Age']]
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0

# %%
#dataframe manipulation 

temp_df = pd.read_csv("titanic.csv")

#change a whole column

#change a specific rows 

temp_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#How to query data? Select

titanic_df[titanic_df["Age"] > 35].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 6             7         0       1
# 11           12         1       1
# 13           14         0       3
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 13      5    347082  31.2750   NaN        S
# 15      0    248706  16.0000   NaN        S

# %%
#Queries multiple columns condition
titanic_df.query('Age > 35 and SibSp == 1').head()


#query and change
temp_df.loc[(temp_df.Survived == 1), 'Fare'] +=10

# %% [markdown]
# #### Exercise : Change age for all male pasengers of titanic to +1 year

# %%
#Your code here

# %%
#applying Functions to dataframes

def my_apply_func(x):
    print(x,"\n")
    return(x)

small_subdataset = titanic_df.iloc[:2,]
small_subdataset.apply( my_apply_func, axis = 1)
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object
#
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# ...

# %%
titanic_df.apply(lambda row : " -- ".join(row.astype(str)), axis =1)
# Out:
# 0      1 -- 0 -- 3 -- Braund, Mr. Owen Harris -- male...
# 1      2 -- 1 -- 1 -- Cumings, Mrs. John Bradley (Flo...
# 2      3 -- 1 -- 3 -- Heikkinen, Miss. Laina -- femal...
# 3      4 -- 1 -- 1 -- Futrelle, Mrs. Jacques Heath (L...
# 4      5 -- 0 -- 3 -- Allen, Mr. William Henry -- mal...
#                              ...
# 886    887 -- 0 -- 2 -- Montvila, Rev. Juozas -- male...
# 887    888 -- 1 -- 1 -- Graham, Miss. Margaret Edith ...
# 888    889 -- 0 -- 3 -- Johnston, Miss. Catherine Hel...
# 889    890 -- 1 -- 1 -- Behr, Mr. Karl Howell -- male...
# 890    891 -- 0 -- 3 -- Dooley, Mr. Patrick -- male -...
# Length: 891, dtype: object

# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
#The difference between numpy arrays and normal list arrays - They are homogonoes 

lstOne = [1,2,3,4,5,6,7,8,9]
print(type(lstOne))
print(lstOne)

lstTwo = np.array(lstOne,dtype=str)
[print(type(lstTwo))]
print(lstTwo)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# <class 'numpy.ndarray'>
# ['1' '2' '3' '4' '5' '6' '7' '8' '9']

# %%
#creating arrays
np.zeros(10, dtype='int')


#creating a 3 row x 5 column matrix
np.ones((3,5), dtype=float)


#creating a matrix with a predefined value
np.full((3,5), 10)

#create an array with a set sequence
np.arange(0, 20, 2)

#create an array of even space between the given range of values
np.linspace(0, 1, 5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
#slicing and indexing is exactly the same as list data strucutre

# %%
# Array Concatenation

#You can concatenate two or more arrays at once.
x = np.array([1, 2, 3])
y = np.array([3, 2, 1])
z = [21,21,21]
np.concatenate([x, y,z])
# Out:
# array([ 1,  2,  3,  3,  2,  1, 21, 21, 21])

# %%
#You can also use this function to create 2-dimensional arrays.
grid = np.array([[1,2,3],[4,5,6]])
np.concatenate([grid,grid])


#Using its axis parameter, you can define row-wise or column-wise matrix
np.concatenate([grid,grid],axis=1)
# Out:
# array([[1, 2, 3, 1, 2, 3],
#        [4, 5, 6, 4, 5, 6]])

# %%
# Let's see Images

#! wget https://github.com/TheDataNomad/AlgoWarzmi/raw/main/Mutrah.jpg

# %%
from PIL import Image

image_object = Image.open("Mutrah.jpg")
image_object
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x405 at 0x1180C36D0>

# %%
image_array = np.asarray( image_object)
image_array.shape
# Out:
# (405, 540, 3)

# %% [markdown]
# # Aggregation and understanding the Data

# %%
#aggregation 
ages = titanic_df["Age"]

# %%
#Mean
ages.mean()
# Out:
# 29.69911764705882

# %%
#Mode
ages.mode()
# Out:
# 0    24.0
# dtype: float64

# %%
#
ages.max()
ages.min()
# Out:
# 0.42

# %%
# Info Function
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Describe Method
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Non-Numerical features

Gender = titanic_df[titanic_df["Sex"] == "female"]["Sex"].count()
Gender
# Out:
# 314
