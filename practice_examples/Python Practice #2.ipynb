# %%
###### START HERE 
import pandas as pd
# !wget 'https://github.com/TheDataNomad/AlgoWarzmi/raw/refs/heads/main/Pokemon.csv'
# Out:
# --2025-02-12 09:44:54--  https://github.com/TheDataNomad/AlgoWarzmi/raw/refs/heads/main/Pokemon.csv
# Resolving github.com (github.com)... 20.233.83.145
# Connecting to github.com (github.com)|20.233.83.145|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/TheDataNomad/AlgoWarzmi/refs/heads/main/Pokemon.csv [following]
# --2025-02-12 09:44:54--  https://raw.githubusercontent.com/TheDataNomad/AlgoWarzmi/refs/heads/main/Pokemon.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8156 (8.0K) [text/plain]
# Saving to: ‘Pokemon.csv’
#
# Pokemon.csv         100%[===================>]   7.96K  --.-KB/s    in 0s
#
# 2025-02-12 09:44:55 (63.8 MB/s) - ‘Pokemon.csv’ saved [8156/8156]

# %%
### Load the dataset into df and show the head
df = pd.read_csv("Pokemon.csv")
df.head()
# Out:
#    ID        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0   1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1   2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2   3    Venusaur  Grass  Poison    525  80      82       83      100
# 3   4  Charmander   Fire     NaN    309  39      52       43       60
# 4   5  Charmeleon   Fire     NaN    405  58      64       58       80
#
#    Sp. Def  Speed  Stage  Legendary
# 0       65     45      1      False
# 1       80     60      2      False
# 2      100     80      3      False
# 3       50     65      1      False
# 4       65     80      2      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      151 non-null    int64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    int64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 14.4+ KB

# %%
df.describe()
# Out:
#                ID      Total          HP      Attack     Defense     Sp. Atk  \
# count  151.000000  151.00000  151.000000  151.000000  151.000000  151.000000
# mean    76.000000  407.07947   64.211921   72.549669   68.225166   67.139073
# std     43.734045   99.74384   28.590117   26.596162   26.916704   28.534199
# min      1.000000  195.00000   10.000000    5.000000    5.000000   15.000000
# 25%     38.500000  320.00000   45.000000   51.000000   50.000000   45.000000
# 50%     76.000000  405.00000   60.000000   70.000000   65.000000   65.000000
# 75%    113.500000  490.00000   80.000000   90.000000   84.000000   87.500000
# max    151.000000  680.00000  250.000000  134.000000  180.000000  154.000000
#
#           Sp. Def       Speed       Stage
# count  151.000000  151.000000  151.000000
# mean    66.019868   68.933775    1.582781
# std     24.197926   26.746880    0.676832
# min     20.000000   15.000000    1.000000
# 25%     49.000000   46.500000    1.000000
# 50%     65.000000   70.000000    1.000000
# 75%     80.000000   90.000000    2.000000
# max    125.000000  140.000000    3.000000

# %%
## Plot a scatter plot to compare the relationship between "HP" and "Attack"
import seaborn as sns

sns.scatterplot(data=df,x='HP',y='Attack')
# Out:
# <Axes: xlabel='HP', ylabel='Attack'>

# %%
import warnings
warnings.filterwarnings("ignore")

sns.pairplot(data=df)

# %%
df
# Out:
#       ID        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# 0         65     45      1      False
# 1         80     60      2      False
# 2        100     80      3      False
# 3         50     65      1      False
# 4         65     80      2      False
# ..       ...    ...    ...        ...
# 146       50     50      1      False
# 147       70     70      2      False
# 148      100     80      3      False
# 149       90    130      1       True
# 150      100    100      1      False
#
# [151 rows x 13 columns]

# %%
sns.heatmap(df.drop("ID",axis=1).corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
# create another subset dataframe called legendary_pokemons and 
# it should include only Legendary Pokemons then print the length of the dataframe

legendary_pokemons = df[df['Legendary']==True]
print(f"Number of Legendary pokemns =  {len(legendary_pokemons)}")

### Extra Task loop through the names and print them

for i in range(len(legendary_pokemons)):
    print(f"The name is {legendary_pokemons.iloc[i]['Name']}")

print("---- METHOD 2 ---- ")
for i, pokemon in legendary_pokemons.iterrows():
    print(f"The name is {pokemon['Name']} and it's Attack is {pokemon['Attack']}")
# Out:
# Number of Legendary pokemns =  4
# The name is Articuno
# The name is Zapdos
# The name is Moltres
# The name is Mewtwo
# ---- METHOD 2 ----
# The name is Articuno and it's Attack is 85
# The name is Zapdos and it's Attack is 90
# The name is Moltres and it's Attack is 100
# The name is Mewtwo and it's Attack is 110

# %%
# create another subset dataframe called grass_poison_pokemons and 
# it should include if any type 1 or 2 is either grass or posion 
# HINT 1: use .isin() to check if it "Grass" or "Poison" list
# HINT 2: FOCUS on the word "OR" and "list"
# HINT 3: AND == &   , OR == |

types_to_check = ["Grass",'Poison']
grass_poison_pokemons = df[(df['Type 1'].isin(types_to_check)) | ((df['Type 2'].isin(types_to_check)))]
#Print the number of pokemons similar to above
print(len(grass_poison_pokemons))
# Out:
# 38

# %%
### Using your choice between seaborn or plotly express:
# plot a bar chart that shows the "count" per "Type 1"
# hint: seaborn has plot specific for "count"
import seaborn as sns

sns.countplot(data=df,x='Type 1')
# Out:
# <Axes: xlabel='Type 1', ylabel='count'>
